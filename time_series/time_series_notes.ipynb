# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from debug import local_settings, timeifdebug, timeargsifdebug, frame_splain

# %%
df = pd.read_csv('instructors/coffee_consumption.csv')
df
# Out:
#            date  coffee_consumption
# 0    2019-01-01           14.301915
# 1    2019-01-02           12.905900
# 2    2019-01-03           10.046015
# 3    2019-01-04            6.354805
# 4    2019-01-07            8.545563
# 5    2019-01-08            9.410101
# 6    2019-01-09            7.219271
# 7    2019-01-10            9.338456
# 8    2019-01-11           11.872667
# 9    2019-01-14            9.198816
# 10   2019-01-15           11.753337
# 11   2019-01-16           11.567694
# 12   2019-01-17            9.429428
# 13   2019-01-18            9.376213
# 14   2019-01-21           11.343439
# 15   2019-01-22           10.945944
# 16   2019-01-23            8.599186
# 17   2019-01-24            8.141553
# 18   2019-01-25            9.421176
# 19   2019-01-28           12.295298
# 20   2019-01-29           10.336273
# 21   2019-01-30           12.488651
# 22   2019-01-31            9.035046
# 23   2019-02-01            9.042273
# 24   2019-02-04           12.673222
# ...

# %%
pd.to_datetime('6 Nov 1973 2:35pm')
# Out:
# Timestamp('1973-11-06 14:35:00')

# %%
frame_splain(df, splain=True, debug=True)
# Out:
# DATAFRAME SHAPE:
# (261, 2)
#
# DATAFRAME INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 2 columns):
# date                  261 non-null object
# coffee_consumption    261 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ KB
# None
#
# DATAFRAME DESCRIPTION:
#                     count       mean       std       min      25%        50%  \
# coffee_consumption  261.0  10.316227  2.119515  5.680393  8.88652  10.149539
#
#                           75%        max
# coffee_consumption  11.753337  17.043445
#
# DATAFRAME HEAD:
#          date  coffee_consumption
# 0  2019-01-01           14.301915
# 1  2019-01-02           12.905900
# 2  2019-01-03           10.046015
# 3  2019-01-04            6.354805
# 4  2019-01-07            8.545563

# %%
df.date = pd.to_datetime(df.date)

# %%
frame_splain(df, splain=True)
# Out:
# DATAFRAME SHAPE:
# (261, 2)
#
# DATAFRAME INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 2 columns):
# date                  261 non-null datetime64[ns]
# coffee_consumption    261 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 4.2 KB
# None
#
# DATAFRAME DESCRIPTION:
#                     count       mean       std       min      25%        50%  \
# coffee_consumption  261.0  10.316227  2.119515  5.680393  8.88652  10.149539
#
#                           75%        max
# coffee_consumption  11.753337  17.043445
#
# DATAFRAME HEAD:
#         date  coffee_consumption
# 0 2019-01-01           14.301915
# 1 2019-01-02           12.905900
# 2 2019-01-03           10.046015
# 3 2019-01-04            6.354805
# 4 2019-01-07            8.545563

# %%
dfd = df.set_index('date')

# %%
dfd=dfd.asfreq('D').fillna(0)

# %%
frame_splain(dfd, splain=True)
# Out:
# DATAFRAME SHAPE:
# (365, 1)
#
# DATAFRAME INFO:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-01-01 to 2019-12-31
# Freq: D
# Data columns (total 1 columns):
# coffee_consumption    365 non-null float64
# dtypes: float64(1)
# memory usage: 5.7 KB
# None
#
# DATAFRAME DESCRIPTION:
#                     count      mean       std  min  25%       50%        75%  \
# coffee_consumption  365.0  7.376809  4.995189  0.0  0.0  9.093397  11.151354
#
#                           max
# coffee_consumption  17.043445
#
# DATAFRAME HEAD:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-05            0.000000

# %%
dfd.head(10)
# Out:
#             coffee_consumption
# date
# 2019-01-01           14.301915
# 2019-01-02           12.905900
# 2019-01-03           10.046015
# 2019-01-04            6.354805
# 2019-01-05            0.000000
# 2019-01-06            0.000000
# 2019-01-07            8.545563
# 2019-01-08            9.410101
# 2019-01-09            7.219271
# 2019-01-10            9.338456

# %%
dfm=dfd.resample('M').agg(['min','mean','max','count'])
dfm
# Out:
#            coffee_consumption
#                           min      mean        max count
# date
# 2019-01-31                0.0  7.546024  14.301915    31
# 2019-02-28                0.0  7.358530  12.673222    28
# 2019-03-31                0.0  7.089645  14.551441    31
# 2019-04-30                0.0  7.401021  14.036570    30
# 2019-05-31                0.0  8.015487  14.952719    31
# 2019-06-30                0.0  6.121883  13.446564    30
# 2019-07-31                0.0  8.008628  17.043445    31
# 2019-08-31                0.0  7.226034  13.665973    31
# 2019-09-30                0.0  7.189633  15.347007    30
# 2019-10-31                0.0  7.875920  16.811112    31
# 2019-11-30                0.0  7.217327  14.741298    30
# 2019-12-31                0.0  7.418920  14.623106    31

# %%
dfd['avg_7d']= dfd.coffee_consumption.rolling(7).mean()
dfd['avg_28d']= dfd.coffee_consumption.rolling(28).mean()

dfd
# Out:
#             coffee_consumption    avg_7d   avg_28d
# date
# 2019-01-01           14.301915       NaN       NaN
# 2019-01-02           12.905900       NaN       NaN
# 2019-01-03           10.046015       NaN       NaN
# 2019-01-04            6.354805       NaN       NaN
# 2019-01-05            0.000000       NaN       NaN
# 2019-01-06            0.000000       NaN       NaN
# 2019-01-07            8.545563  7.450600       NaN
# 2019-01-08            9.410101  6.751769       NaN
# 2019-01-09            7.219271  5.939394       NaN
# 2019-01-10            9.338456  5.838314       NaN
# 2019-01-11           11.872667  6.626580       NaN
# 2019-01-12            0.000000  6.626580       NaN
# 2019-01-13            0.000000  6.626580       NaN
# 2019-01-14            9.198816  6.719902       NaN
# 2019-01-15           11.753337  7.054650       NaN
# 2019-01-16           11.567694  7.675853       NaN
# 2019-01-17            9.429428  7.688849       NaN
# ...

# %%
dfd[['avg_7d','avg_28d']].plot()
plt.show()

# %%
dfdml = dfd.resample('M').agg(['min', 'max'])
dfdml
# Out:
#            coffee_consumption               avg_7d             avg_28d  \
#                           min        max       min       max       min
# date
# 2019-01-31                0.0  14.301915  5.838314  7.688849  7.024033
# 2019-02-28                0.0  12.673222  6.721600  7.996775  7.120014
# 2019-03-31                0.0  14.551441  6.162478  8.958001  6.816840
# 2019-04-30                0.0  14.036570  6.768095  8.396673  7.079875
# 2019-05-31                0.0  14.952719  6.501499  8.553503  6.897575
# 2019-06-30                0.0  13.446564  5.682040  8.512600  6.559160
# 2019-07-31                0.0  17.043445  4.998682  9.025116  6.465239
# 2019-08-31                0.0  13.665973  6.663779  8.478430  7.302767
# 2019-09-30                0.0  15.347007  6.215356  8.385222  7.159935
# 2019-10-31                0.0  16.811112  6.437773  8.273503  7.054584
# 2019-11-30                0.0  14.741298  6.729524  8.541941  7.206376
# ...

# %%
dfdml.avg_7d
# Out:
#                  min       max
# date
# 2019-01-31  5.838314  7.688849
# 2019-02-28  6.721600  7.996775
# 2019-03-31  6.162478  8.958001
# 2019-04-30  6.768095  8.396673
# 2019-05-31  6.501499  8.553503
# 2019-06-30  5.682040  8.512600
# 2019-07-31  4.998682  9.025116
# 2019-08-31  6.663779  8.478430
# 2019-09-30  6.215356  8.385222
# 2019-10-31  6.437773  8.273503
# 2019-11-30  6.729524  8.541941
# 2019-12-31  6.408350  8.327099

# %%
dfdml.avg_7d['min']
# Out:
# date
# 2019-01-31    5.838314
# 2019-02-28    6.721600
# 2019-03-31    6.162478
# 2019-04-30    6.768095
# 2019-05-31    6.501499
# 2019-06-30    5.682040
# 2019-07-31    4.998682
# 2019-08-31    6.663779
# 2019-09-30    6.215356
# 2019-10-31    6.437773
# 2019-11-30    6.729524
# 2019-12-31    6.408350
# Freq: M, Name: min, dtype: float64

# %%
dfd.coffee_consumption.resample('M').agg(['min', 'max'])
# Out:
#             min        max
# date
# 2019-01-31  0.0  14.301915
# 2019-02-28  0.0  12.673222
# 2019-03-31  0.0  14.551441
# 2019-04-30  0.0  14.036570
# 2019-05-31  0.0  14.952719
# 2019-06-30  0.0  13.446564
# 2019-07-31  0.0  17.043445
# 2019-08-31  0.0  13.665973
# 2019-09-30  0.0  15.347007
# 2019-10-31  0.0  16.811112
# 2019-11-30  0.0  14.741298
# 2019-12-31  0.0  14.623106

# %%
dfdml.columns
# Out:
# MultiIndex(levels=[['coffee_consumption', 'avg_7d', 'avg_28d'], ['min', 'max']],
#            codes=[[0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1]])

# %%
dfdml.columns = [p1 + '_' + p2 for p1, p2 in dfdml.columns]
dfdml.columns
# Out:
# Index(['coffee_consumption_min', 'coffee_consumption_max', 'avg_7d_min',
#        'avg_7d_max', 'avg_28d_min', 'avg_28d_max'],
#       dtype='object')

# %%
dfdml
# Out:
#             coffee_consumption_min  coffee_consumption_max  avg_7d_min  \
# date
# 2019-01-31                     0.0               14.301915    5.838314
# 2019-02-28                     0.0               12.673222    6.721600
# 2019-03-31                     0.0               14.551441    6.162478
# 2019-04-30                     0.0               14.036570    6.768095
# 2019-05-31                     0.0               14.952719    6.501499
# 2019-06-30                     0.0               13.446564    5.682040
# 2019-07-31                     0.0               17.043445    4.998682
# 2019-08-31                     0.0               13.665973    6.663779
# 2019-09-30                     0.0               15.347007    6.215356
# 2019-10-31                     0.0               16.811112    6.437773
# 2019-11-30                     0.0               14.741298    6.729524
# 2019-12-31                     0.0               14.623106    6.408350
#
# ...
